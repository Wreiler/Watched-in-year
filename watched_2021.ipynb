# %% [markdown]
# ### Сводная таблица

# %%
from IPython.display import display
from IPython.display import clear_output
from ipywidgets import Dropdown
from films import *

dropdown1 = Dropdown(
    options = [('По дате просмотра', 1), ('По алфавиту', 2)],
    value = 1,
    description='Сортировка:' 
)

def on_button_clicked(b):
    clear_output(wait=True)
    display(dropdown1)
    svod_table(b['new'])

dropdown1.observe(on_button_clicked, names='value')
analys()
display(dropdown1)
svod_table(1)
# Out:
# Dropdown(description='Сортировка:', options=(('По дате просмотра', 1), ('По алфавиту', 2)), value=1)
# <style  type="text/css" >
#     #T_c03d44a5_7866_11eb_a5bc_1c1b0d36d8ffrow0_col0 {
#             background-color:  #222430;
#             color:  #95abab;
#             border-style:  solid;
#             border-width:  1px;
#             border-color:  #733737;
#             max-width:  450px;
#             font-size:  10pt;
#             text-align:  center;
#             : ;
#             : ;
#             : ;
#         }    #T_c03d44a5_7866_11eb_a5bc_1c1b0d36d8ffrow0_col1 {
#             background-color:  #222430;
#             color:  #95abab;
#             border-style:  solid;
#             border-width:  1px;
#             border-color:  #733737;
#             max-width:  450px;
#             font-size:  10pt;
#             text-align:  center;
#             : ;
#             : ;
#             : ;
#         }    #T_c03d44a5_7866_11eb_a5bc_1c1b0d36d8ffrow1_col0 {
# ...

# %% [markdown]
# ### Добавление последнего просмотренного фильма или сериала:

# %%
from films import *
input_film()
# Out:
# Последний просмотренный фильм или сериал: Касабланка
# Дата просмотра последнего фильма или сериала (DD-MM): 26-02

# %% [markdown]
# ### Подсчет количества фильмов и расстояния до цели:

# %%
from films import *
analys()
count_films()
# Out:
# Вы посмотрели 29 фильмов с начала 2021-го года
#
#
# ДО ЦЕЛИ ОСТАЛОСЬ ПОСМОТРЕТЬ 271 ФИЛЬМ ДО КОНЦА ЭТОГО ГОДА!

# %% [markdown]
# ### Подсчет количества сериалов:

# %%
count_ser()
# Out:
# Вы посмотрели 1 сериал с начала 2021-го года

# %% [markdown]
# ________________________________________________________________

# %% [markdown]
# ### Последний просмотренный фильм

# %%
last_film()
# Out:
# Последний просмотренный фильм на сегодняшний день - "Касабланка"
# Просмотрен: [26-02-2021]

# %% [markdown]
# ### Последний просмотренный сериал (сезон сериала)

# %%
last_show()
# Out:
# Последний просмотренный сериал (сезон сериала) на сегодняшний день - "Твин Пикс (3 сезона)"
# Закончен просмотр: [08-02-2021]

# %% [markdown]
# ### Вывод списка фильмов (в алфавитном порядке)

# %%
all_films()
# Out:
# Восемь С Половиной
# Гарри Поттер И Дары Смерти. Часть 1
# Гарри Поттер И Дары Смерти. Часть 2
# Гарри Поттер И Кубок Огня
# Гарри Поттер И Орден Феникса
# Гарри Поттер И Принц-Полукровка
# Гарри Поттер И Тайная Комната
# Гарри Поттер И Узник Азкабана
# Гарри Поттер И Философский Камень
# Душа
# Еще По Одной
# Земля Кочевников
# Каникулы Господина Юло
# Касабланка
# Лето С Моникой
# Лолита
# Осенняя Соната
# Рай И Ад
# С Широко Закрытыми Глазами
# Сансет Бульвар
# Седьмая Печать
# Синий Бархат
# Служанка
# Сцены Из Супружеской Жизни
# Твин Пикс: Огонь, Иди Со Мной
# Харакири
# Холодная Война
# Час Волка
# Шепоты И Крики

# %% [markdown]
# ### Вывод списка сериалов (в алфавитном порядке) и посчет сезонов

# %%
ser_res()
# Out:
# Твин Пикс (3 сезона)
#
# Всего сезонов: 3
